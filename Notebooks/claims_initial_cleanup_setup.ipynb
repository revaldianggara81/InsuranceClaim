# %%
#clear bronze , silver & gold

# %%
# %sql
---delete from claims_bronze.claims_db.inbound_claims

# %%
# %sql
delete from claims_silver.claims_db.claim_evidence_summary

# %%
# %sql
select *  from claims_silver.claims_db.claim_evidence_summary

# %%
# %sql
select *  from claims_gold.claims_db.claim_decision

# %%
# %sql
select * from claims_bronze.claims_db.inbound_claims

# %%
# %sql
/* INSERT INTO claims_bronze.claims_db.inbound_claims (
  inbox_id,
  claim_id_ext,
  policy_id,
  incident_ts,
  location_lat,
  location_lon,
  narrative,
  video_uri_claimant,
  image_uri_claimant,
  image_uri_counterparty,
  status,
  created_at
)
VALUES (
  1,
  'MOB-CLM-003',
  'TX-INS-45678',
  TIMESTAMP('2025-09-17 14:32:00'),
  '33.1523',
  '-96.8235',
  'Right-of-way at stop-controlled intersection; struck by red SUV from the right.',
  '/Volumes/claims_bronze/claims_db/evidence/claimant_video_evidence/CarCollision.mp4',
  '/Volumes/claims_bronze/claims_db/evidence/claimant_img_evidence/yellow_car.png',
  '/Volumes/claims_bronze/claims_db/evidence/counterparty_img_evidence/red_car.png',
  'RECEIVED',
  TIMESTAMP('2025-09-18 03:37:03.057274')
);
*/

# %%
# %sql
select *  from claims_bronze.claims_db.inbound_claims

# %%
print("****Initail Cleanup Done Successfully****")
